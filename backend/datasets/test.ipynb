# %%
import pandas as pd
import numpy as np

# %%
volkswagen_all_columns = pd.read_csv('volkswagen_cleaned.csv')
audi_all_columns = pd.read_csv('audi_cleaned.csv')
mercedes_all_columns = pd.read_csv('mercedes_cleaned.csv')

# %%
df[df['year'] == 2024]
# Out:
#        displacement doors   fuel  kilowatts    location   manufacturer  \
# 6408            2.0   4/5  Dizel      110.0      Mostar  Mercedes-Benz
# 9914            2.0   4/5  Dizel      110.0  Banja Luka  Mercedes-Benz
# 10204           2.2   4/5  Dizel      145.0    Busovača  Mercedes-Benz
# 10421           3.0   4/5  Dizel      270.0    Živinice  Mercedes-Benz
# 10712           3.0   4/5  Dizel      270.0    Ljubuški  Mercedes-Benz
# 11346           2.2   4/5  Dizel      120.0      Mostar  Mercedes-Benz
# 11602           2.0   4/5  Dizel      180.0    Živinice  Mercedes-Benz
# 11603           2.0   4/5  Dizel      160.0  Banja Luka  Mercedes-Benz
# 12216           3.0   4/5  Dizel      184.0      Mostar  Mercedes-Benz
#
#        mileage    model   price  \
# 6408       0.0  CLA 200  101006
# 9914       5.0    A 200  103990
# 10204   9000.0    E 220  142000
# 10421   7800.0  GLE 450  243900
# 10712      0.0    S 450  305990
# 11346      0.0    V 220  159529
# 11602      0.0  GLE 300  195952
# 11603    820.0      EQA  150000
# 12216      0.0    G 400  319000
#
#                                                    title  ...   color  \
# 6408            Mercedes-Benz CLA 200d 2024 *NOVI MODEL*  ...    Crna
# 9914   Mercedes-Benz A 200d AMG Line/MLED/150KS FACELIFT  ...  Bijela
# 10204                Mercedes-Benz E 220 2024 novi model  ...    Crna
# 10421             Mercedes-Benz GLE 450d 4matic AMG Line  ...    Crna
# 10712  Mercedes S 450d 4x4 Long 9G AMG DIGI LIGHT PAN...  ...    Crna
# 11346           Mercedes-Benz V 220d Extra Long *AKCIJA*  ...    Crna
# 11602                         Mercedes-Benz GLE 300 d 4M  ...    Crna
# 11603                      Mercedes-Benz E220 4matic EQA  ...   Plava
# 12216                   MERCEDES G400 AMG PAKET 2024 NOV  ...    Siva
#
#       cruiseControl  drivetrain emissionStandard rimSize  transmission  \
# 6408           True     Prednji           Euro 6    18.0     Automatik
# 9914           True     Prednji           Euro 6    18.0     Automatik
# 10204         False      Zadnji           Euro 5    18.0     Automatik
# 10421          True  Sva četiri           Euro 6    21.0     Automatik
# 10712          True  Sva četiri           Euro 6    21.0     Automatik
# 11346          True      Zadnji           Euro 6    18.0     Automatik
# 11602          True  Sva četiri           Euro 6    16.0     Automatik
# 11603         False  Sva četiri           Euro 5    16.0     Automatik
# 12216         False  Sva četiri           Euro 5    16.0     Automatik
#
#                 type airCondition  navigation  registration
# 6408   Sportski/kupe        False        True         False
# 9914        Limuzina        False        True         False
# 10204       Limuzina        False       False         False
# 10421        Terenac        False        True          True
# 10712       Limuzina        False        True         False
# 11346          Kombi        False        True         False
# 11602            SUV        False        True         False
# 11603       Limuzina        False       False         False
# 12216    unavailable        False       False         False
#
# [9 rows x 21 columns]

# %%
df.loc[11965, 'year'] = 1990
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.loc[11965, 'year'] = 1990
#
# NameError: name 'df' is not defined

# %%
df.to_csv('mercedes_cleaned.csv', index=False)

# %%
df2[df2['year'] == 1975]
# Out:
# Empty DataFrame
# Columns: [displacement, doors, fuel, kilowatts, location, manufacturer, mileage, model, price, title, year, color, cruiseControl, drivetrain, emissionStandard, rimSize, transmission, type, airCondition, navigation, registration]
# Index: []
#
# [0 rows x 21 columns]

# %%
df = pd.concat([volkswagen_all_columns, audi_all_columns, mercedes_all_columns], ignore_index=True)

# %%
df.to_csv('all_cars.csv', index=False)
